# %%
# print("code_part")
# code_part = int(dbutils.widgets.text("code_part", ""))
# print(code_part)

# Inside get_all_table_data_dictionary notebook
dbutils.widgets.text("source_name", "")
dbutils.widgets.text("code_part", "")

source_name = dbutils.widgets.get("source_name")
code_part = int(dbutils.widgets.get("code_part"))

if code_part == 1:

    source_name = dbutils.widgets.text("source_name", "")
    print(source_name)
    source_query = "select * from public.vendors"
    print(source_query)
    dbutils.notebook.exit(source_query)

# %%
if code_part == 1:

    source_name = dbutils.widgets.text("source_name", "")
    print(source_name)
    source_query = "select * from public.vendors"
    print(source_query)
    dbutils.notebook.exit(source_query)

# %%
if code_part == 2:
    
    bucket_name = dbutils.widgets.get("s3_bucket")
    dd_file_name = dbutils.widgets.get("dd_file_name")

    view_name = "tb" + dd_file_name[:-8]
    print(bucket_name)
    print(view_name)

    print("2")
    dbutils.notebook.exit("Success")
